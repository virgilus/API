# %% [markdown]
# # ISS API

# %% [markdown]
# ## Exercice (medium)
#
# The goal of this notebook is to use an API and generate a Leaflet map showing the current position of the ISS.
#
# * The API we are going to use is available here: [http://api.open-notify.org/](http://api.open-notify.org/)
# * The Folium documentation is here: [https://python-visualization.github.io/folium/index.html](https://python-visualization.github.io/folium/index.html), but the first chapter should be enough: [https://python-visualization.github.io/folium/quickstart.html](https://python-visualization.github.io/folium/quickstart.html)
#
# **TIPS**
#
# * When you create the map, use the parameters `location` and `zoom_start` so it automatically displays the area we are looking for.
#
# **Bonus**
#
# * Modify the tooltip property of the Folium Marker so it displays the latitude and longitude when you click on it.

# %%
# Code here!

# %% [markdown]
# ## Exercice (medium / difficult)
#
# The goal is to draw a line showing the trajectory of the ISS. To do so:
#
# * Create a loop that runs every 5 seconds and takes 12 measurements (latitude, longitude). This means your program should run for 1 minute. Store all this data in a list of tuples.
# * Once this is done, use the `Polyline` function from Folium to draw the line.
#
# **TIPS**
#
# * Use the `time` library to make the program pause for 5 seconds between each measurement.
# * Use the `color` parameter of `Polyline` to make the line red — it looks cleaner.
# * Use several Jupyter cells. Once you have the data (the coordinates), there is no need to wait 1 minute every time you modify your map.

# %%
# Code here!

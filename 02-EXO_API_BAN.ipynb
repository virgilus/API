# %% [markdown]
# # Practical Exercise: Retrieve Address Coordinates
#
# ## API Call to Get Geographic Coordinates
#
# Write a function that takes an address (stored as a string) as input and returns the geographic coordinates (latitude and longitude) of this address using the National Address Database API (BAN).
#
# Documentation:
# https://geoservices.ign.fr/documentation/services/services-geoplateforme/geocodage
#
# Swagger: https://data.geopf.fr/geocodage/openapi
#
# (Swagger is a set of open-source tools built around the OpenAPI Specification that can help you design, build, document, and consume REST APIs.)
#
# API Capabilities:
# https://data.geopf.fr/geocodage/getCapabilities

# %%
# Code here
import requests

# %% [markdown]
# ## Bulk Geocoding with the National Address Database API
#
# The "data" folder contains a file named "prefectures.csv". Write an automated Python script that retrieves the coordinates (latitude and longitude) of each prefecture using the National Address Database API. This time, use bulk geocoding to optimize API calls.
#
# The script should then save the results to a new CSV file by adding two columns: latitude and longitude.
#
# The URL is: https://data.geopf.fr/geocodage/search/csv

# %%
# Code here!
